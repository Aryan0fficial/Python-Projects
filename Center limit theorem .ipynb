# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
import plotly.express as px
import joblib
import pickle

# %%
df=pd.read_excel(r'E:\Data Analytics\Python\Python Datas\Superstore.xlsx')
# Out:
# C:\Users\KUMAR COMPUTERS\anaconda3\Lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")

# %%
# 10 percent of this dataset
len(df)*10/100
# Out:
# 999.4

# %%
# 10 percent of this dataset 2nd way
len(df)/100*10
# Out:
# 999.4

# %%
# get the sample data of sales column
sample_sls = df['Sales'].sample(500)
sample_sls.head()
# Out:
# 6387    10.560
# 418      5.780
# 9099    10.368
# 4575    13.900
# 6697    54.960
# Name: Sales, dtype: float64

# %%
# mean and standerd of sample data 
sample_mean = sample_sls.mean()
sample_std = sample_sls.std()

print('Sample Mean',sample_mean.round(2))
print('Sample Std',sample_std)
# Out:
# Sample Mean 216.44
# Sample Std 644.3256095442864

# %%
# check mean of sales column
df['Sales'].mean()
# Out:
# np.float64(229.85800083049833)

# %%
df['Sales'].std()
# Out:
# 623.2451005086818

# %%
smpl_mean = []
for i in range(1000):
    smpl_data = df['Sales'].sample(50)
    smpl_mean.append(smpl_data.mean())

# %%
len(smpl_data)
# Out:
# 50

# %%
plt.hist(smpl_mean,bins=30)
plt.show()

# %%
fig=px.histogram(smpl_mean,nbins=60)
fig.update_layout(width=750)
fig.show()

# %%
# check data kitna fela hua h
fig=px.box(sample_sls)
fig.update_layout(height=400,width=700)
fig.show()

# %%
fig=px.box(smpl_mean)
fig.show()

# %%
smpl_mean = []
for i in range(1000):
    smpl_data = df['Sales'].sample(50)
    smpl_mean.append(smpl_data.mean())

# %%
smpl_mean = pd.DataFrame({'Sales':smpl_mean}).round(2)
smpl_mean.head()
# Out:
#     Sales
# 0  187.15
# 1  239.30
# 2  215.87
# 3  167.56
# 4  282.96

# %%
fig=px.box(smpl_mean)
fig.show()
